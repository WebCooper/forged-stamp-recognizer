# %%
import sys
import cv2
import tensorflow as tf
from pathlib import Path
import os

print("Python:", sys.version)
print("OpenCV:", cv2.__version__)
print("TensorFlow:", tf.__version__)
print("Detected GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# Python: 3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]
# OpenCV: 4.13.0
# TensorFlow: 2.21.0
# Detected GPUs: []

# %%
DATASET_ROOT = Path(os.getenv("STAMP_DATASET_ROOT", ""))
if DATASET_ROOT.exists():
    print("Dataset root exists:", DATASET_ROOT.exists())

    for folder in DATASET_ROOT.iterdir():
        if folder.is_dir():
            print(folder.name)
else:
    print("Dataset root does not exist. Set STAMP_DATASET_ROOT to your local dataset path.")
# Out:
# Dataset root exists: True
